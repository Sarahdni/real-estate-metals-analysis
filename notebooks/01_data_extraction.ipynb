# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Real Estate Data Extraction Example\n",
    "\n",
    "This notebook demonstrates how to use the `RealEstateExtractor` to fetch and clean real estate data."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "import sys\n",
    "sys.path.append('..')\n",
    "\n",
    "from src.extractors import RealEstateExtractor"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Configure the extractor\n",
    "config = {\n",
    "    'api_key': 'your_api_key_here',\n",
    "    'start_date': '2023-01-01',\n",
    "    'end_date': '2023-12-31',\n",
    "    'region': 'New York'\n",
    "}\n",
    "\n",
    "# Create extractor instance\n",
    "extractor = RealEstateExtractor(config)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Extract data\n",
    "df = extractor.extract()\n",
    "df.head()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
